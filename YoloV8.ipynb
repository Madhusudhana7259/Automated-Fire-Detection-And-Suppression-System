# %%
# !nvidia-smi
# Out:
# Tue Dec 19 10:38:13 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 660.5/660.5 kB 9.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect mode = train model=yolov8n.pt data=/content/drive/MyDrive/Actual3/Data/data.yaml  epochs=60 imgsz=640
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 134MB/s]
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !zip -r /content/runs.zip /content/runs/
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/train/ (stored 0%)
#   adding: content/runs/detect/train/train_batch0.jpg (deflated 2%)
#   adding: content/runs/detect/train/labels.jpg (deflated 40%)
#   adding: content/runs/detect/train/val_batch0_labels.jpg (deflated 12%)
#   adding: content/runs/detect/train/train_batch16650.jpg (deflated 10%)
#   adding: content/runs/detect/train/PR_curve.png (deflated 27%)
#   adding: content/runs/detect/train/train_batch1.jpg (deflated 3%)
#   adding: content/runs/detect/train/events.out.tfevents.1702982329.2d551c09f227.2187.0 (deflated 91%)
#   adding: content/runs/detect/train/F1_curve.png (deflated 18%)
#   adding: content/runs/detect/train/val_batch2_labels.jpg (deflated 12%)
#   adding: content/runs/detect/train/train_batch16651.jpg (deflated 9%)
#   adding: content/runs/detect/train/results.png (deflated 7%)
# ...
